# %%
import pandas as pd

# %%
df = pd.read_csv('ML_Project_SNR_Minus5.csv')

# %%
df
# Out:
#         0.000000000000000000e+00  0.000000000000000000e+00.1  \
# 0                            1.0                    1.302275
# 1                            1.0                    1.233753
# 2                            1.0                    1.303249
# 3                            1.0                    1.284394
# 4                            1.0                    1.316451
# ...                          ...                         ...
# 311995                       0.0                    0.988428
# 311996                       0.0                    0.991334
# 311997                       0.0                    0.970140
# 311998                       0.0                    1.032394
# 311999                       0.0                    1.004090
#
#         0.000000000000000000e+00.2  0.000000000000000000e+00.3  \
# 0                      -148.383246                    8.859367
# 1                        18.771329                   -1.479467
# ...

# %%
df.columns = ['dev_id', 'power', 'sum_real', 'sum_imaginary', 'var_real', 'var_imaginary', 'range_real', 'range_imag', 'real_skew', 'imag_skew', 'real_kurt', 'imag_kurt']

# %%
df
# Out:
#         dev_id     power    sum_real  sum_imaginary  var_real  var_imaginary  \
# 0          1.0  1.302275 -148.383246       8.859367  0.647134       0.652920
# 1          1.0  1.233753   18.771329      -1.479467  0.622038       0.611679
# 2          1.0  1.303249  -72.414643      18.445490  0.660148       0.642540
# 3          1.0  1.284394    0.828373       5.848109  0.654443       0.629948
# 4          1.0  1.316451  -31.339765     -20.200707  0.636542       0.679769
# ...        ...       ...         ...            ...       ...            ...
# 311995     0.0  0.988428  -19.851018     103.916798  0.502895       0.484407
# 311996     0.0  0.991334   67.828097     -38.411368  0.496261       0.494461
# 311997     0.0  0.970140   44.460369     -23.387465  0.484325       0.485561
# 311998     0.0  1.032394   21.267066     -65.676425  0.502799       0.529116
# 311999     0.0  1.004090   53.653991       6.690110  0.498774       0.505022
#
# ...

# %%
seriesObj = df.apply(lambda x: True if x['dev_id'] > 0 else False , axis=1)

# %%
numOfRows = len(seriesObj[seriesObj == True].index)

# %%
print('Number of Rows in dataframe in which signal is transmitted : ', numOfRows)
# Out:
# Number of Rows in dataframe in which signal is transmitted :  17412

# %%
signal_exist = df["dev_id"] > 0

# %%
df_signal_exist = df.loc[signal_exist]

# %%
df_signal_exist.shape
# Out:
# (17412, 12)

# %%
signal_no_exist = (df["dev_id"] == 0.0)

# %%
df_signal_no_exist = df.loc[signal_no_exist]

# %%
df_signal_no_exist.shape
# Out:
# (294588, 12)

# %%
df_signal_exist
# Out:
#         dev_id     power    sum_real  sum_imaginary  var_real  var_imaginary  \
# 0          1.0  1.302275 -148.383246       8.859367  0.647134       0.652920
# 1          1.0  1.233753   18.771329      -1.479467  0.622038       0.611679
# 2          1.0  1.303249  -72.414643      18.445490  0.660148       0.642540
# 3          1.0  1.284394    0.828373       5.848109  0.654443       0.629948
# 4          1.0  1.316451  -31.339765     -20.200707  0.636542       0.679769
# ...        ...       ...         ...            ...       ...            ...
# 286916     1.0  1.309812  -13.550001      31.472982  0.655313       0.654381
# 286917     1.0  1.270622    1.608629      76.102292  0.624440       0.645599
# 286918     1.0  1.281205   -5.394464     -45.940252  0.627004       0.653986
# 286919     1.0  1.301225  -19.605232     -64.854769  0.671152       0.629611
# 286920     1.0  1.328601  -36.749274      35.265683  0.664851       0.663489
#
# ...

# %%
df_signal_no_exist
# Out:
#         dev_id     power   sum_real  sum_imaginary  var_real  var_imaginary  \
# 1050       0.0  0.989097  20.566411     -26.862397  0.495371       0.493611
# 1051       0.0  1.022378 -53.375517      30.147536  0.521523       0.500477
# 1052       0.0  1.004948 -35.400818      36.200485  0.490351       0.514339
# 1053       0.0  1.016567 -50.525922      43.191360  0.492742       0.523381
# 1054       0.0  1.001843  11.379094     -69.494562  0.492097       0.509248
# ...        ...       ...        ...            ...       ...            ...
# 311995     0.0  0.988428 -19.851018     103.916798  0.502895       0.484407
# 311996     0.0  0.991334  67.828097     -38.411368  0.496261       0.494461
# 311997     0.0  0.970140  44.460369     -23.387465  0.484325       0.485561
# 311998     0.0  1.032394  21.267066     -65.676425  0.502799       0.529116
# 311999     0.0  1.004090  53.653991       6.690110  0.498774       0.505022
#
# ...

# %%
df_signal_exist_5000 = df_signal_exist.head(5000)

# %%
df_signal_exist_5000.shape
# Out:
# (5000, 12)

# %%
df_signal_not_exist_5000 = df_signal_no_exist.head(5000)

# %%
df_signal_not_exist_5000.shape
# Out:
# (5000, 12)

# %%
df_signal_exist_5000.drop(['dev_id'], axis = 1, inplace=True)
# Out:
# /home/manash/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_signal_exist_5000.shape
# Out:
# (5000, 11)

# %%
df_signal_exist_5000
# Out:
#           power    sum_real  sum_imaginary  var_real  var_imaginary  \
# 0      1.302275 -148.383246       8.859367  0.647134       0.652920
# 1      1.233753   18.771329      -1.479467  0.622038       0.611679
# 2      1.303249  -72.414643      18.445490  0.660148       0.642540
# 3      1.284394    0.828373       5.848109  0.654443       0.629948
# 4      1.316451  -31.339765     -20.200707  0.636542       0.679769
# ...         ...         ...            ...       ...            ...
# 79130  1.290493   17.679205      31.291752  0.647077       0.643286
# 79131  1.391298    0.535995      46.465284  0.687326       0.703754
# 79132  1.290266  -14.701503     -45.240964  0.637906       0.652133
# 79133  1.369671   18.016990       7.325840  0.685604       0.684028
# 79134  1.324680   61.035621     -28.515046  0.655898       0.668326
#
#        range_real  range_imag  real_skew  imag_skew  real_kurt  imag_kurt
# 0        6.086627    5.817704   0.015940  -0.031028   0.089002   0.076348
# ...

# %%
df_signal_not_exist_5000.drop(['dev_id'], axis = 1, inplace=True)
# Out:
# /home/manash/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_signal_not_exist_5000.shape
# Out:
# (5000, 11)

# %%
df_signal_not_exist_5000
# Out:
#          power   sum_real  sum_imaginary  var_real  var_imaginary  range_real  \
# 1050  0.989097  20.566411     -26.862397  0.495371       0.493611    4.838952
# 1051  1.022378 -53.375517      30.147536  0.521523       0.500477    5.183676
# 1052  1.004948 -35.400818      36.200485  0.490351       0.514339    4.874140
# 1053  1.016567 -50.525922      43.191360  0.492742       0.523381    4.595108
# 1054  1.001843  11.379094     -69.494562  0.492097       0.509248    4.976890
# ...        ...        ...            ...       ...            ...         ...
# 6045  1.006118   1.031136     -37.629720  0.500504       0.505472    4.696343
# 6046  0.988552 -16.948006       7.459322  0.487218       0.501299    5.354748
# 6047  0.951247 -32.409147      14.053732  0.472221       0.478901    4.750605
# 6048  1.010960 -79.683144     -96.340756  0.496925       0.512464    4.677043
# 6049  1.020221   3.186988       7.187735  0.521947       0.498268    5.085673
#
# ...

# %%
df_signal_exist_5000['Signal'] = 1
# Out:
# /home/manash/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_signal_exist_5000.shape
# Out:
# (5000, 12)

# %%
df_signal_exist_5000
# Out:
#           power    sum_real  sum_imaginary  var_real  var_imaginary  \
# 0      1.302275 -148.383246       8.859367  0.647134       0.652920
# 1      1.233753   18.771329      -1.479467  0.622038       0.611679
# 2      1.303249  -72.414643      18.445490  0.660148       0.642540
# 3      1.284394    0.828373       5.848109  0.654443       0.629948
# 4      1.316451  -31.339765     -20.200707  0.636542       0.679769
# ...         ...         ...            ...       ...            ...
# 79130  1.290493   17.679205      31.291752  0.647077       0.643286
# 79131  1.391298    0.535995      46.465284  0.687326       0.703754
# 79132  1.290266  -14.701503     -45.240964  0.637906       0.652133
# 79133  1.369671   18.016990       7.325840  0.685604       0.684028
# 79134  1.324680   61.035621     -28.515046  0.655898       0.668326
#
#        range_real  range_imag  real_skew  imag_skew  real_kurt  imag_kurt  \
# 0        6.086627    5.817704   0.015940  -0.031028   0.089002   0.076348
# ...

# %%
df_signal_not_exist_5000['Signal'] = 0
# Out:
# /home/manash/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_signal_not_exist_5000.shape
# Out:
# (5000, 12)

# %%
df_signal_not_exist_5000
# Out:
#          power   sum_real  sum_imaginary  var_real  var_imaginary  range_real  \
# 1050  0.989097  20.566411     -26.862397  0.495371       0.493611    4.838952
# 1051  1.022378 -53.375517      30.147536  0.521523       0.500477    5.183676
# 1052  1.004948 -35.400818      36.200485  0.490351       0.514339    4.874140
# 1053  1.016567 -50.525922      43.191360  0.492742       0.523381    4.595108
# 1054  1.001843  11.379094     -69.494562  0.492097       0.509248    4.976890
# ...        ...        ...            ...       ...            ...         ...
# 6045  1.006118   1.031136     -37.629720  0.500504       0.505472    4.696343
# 6046  0.988552 -16.948006       7.459322  0.487218       0.501299    5.354748
# 6047  0.951247 -32.409147      14.053732  0.472221       0.478901    4.750605
# 6048  1.010960 -79.683144     -96.340756  0.496925       0.512464    4.677043
# 6049  1.020221   3.186988       7.187735  0.521947       0.498268    5.085673
#
# ...

# %%
concatenate = pd.concat([df_signal_exist_5000, df_signal_not_exist_5000], axis=0)

# %%
concatenate.shape
# Out:
# (10000, 12)

# %%
concatenate
# Out:
#          power    sum_real  sum_imaginary  var_real  var_imaginary  \
# 0     1.302275 -148.383246       8.859367  0.647134       0.652920
# 1     1.233753   18.771329      -1.479467  0.622038       0.611679
# 2     1.303249  -72.414643      18.445490  0.660148       0.642540
# 3     1.284394    0.828373       5.848109  0.654443       0.629948
# 4     1.316451  -31.339765     -20.200707  0.636542       0.679769
# ...        ...         ...            ...       ...            ...
# 6045  1.006118    1.031136     -37.629720  0.500504       0.505472
# 6046  0.988552  -16.948006       7.459322  0.487218       0.501299
# 6047  0.951247  -32.409147      14.053732  0.472221       0.478901
# 6048  1.010960  -79.683144     -96.340756  0.496925       0.512464
# 6049  1.020221    3.186988       7.187735  0.521947       0.498268
#
#       range_real  range_imag  real_skew  imag_skew  real_kurt  imag_kurt  \
# 0       6.086627    5.817704   0.015940  -0.031028   0.089002   0.076348
# ...

# %%
concatenate_normalized=(concatenate-concatenate.min())/(concatenate.max()-concatenate.min())

# %%
concatenate_normalized
# Out:
#          power  sum_real  sum_imaginary  var_real  var_imaginary  range_real  \
# 0     0.742082  0.000000       0.502361  0.679459       0.723675    0.521226
# 1     0.605257  0.569350       0.470347  0.590333       0.572724    0.458260
# 2     0.744027  0.258759       0.532045  0.725679       0.685680    0.676472
# 3     0.706376  0.508234       0.493037  0.705415       0.639589    0.399867
# 4     0.770388  0.398665       0.412376  0.641844       0.821945    0.368070
# ...        ...       ...            ...       ...            ...         ...
# 6045  0.150718  0.508924       0.358406  0.158718       0.183983    0.175120
# 6046  0.115640  0.447685       0.498026  0.111533       0.168710    0.339027
# 6047  0.041152  0.395023       0.518446  0.058275       0.086727    0.188628
# 6048  0.160386  0.234001       0.176605  0.146005       0.209577    0.170315
# 6049  0.178878  0.516268       0.497185  0.234869       0.157617    0.272042
#
# ...

# %%
concatenate_normalized
# Out:
#          power  sum_real  sum_imaginary  var_real  var_imaginary  range_real  \
# 0     0.742082  0.000000       0.502361  0.679459       0.723675    0.521226
# 1     0.605257  0.569350       0.470347  0.590333       0.572724    0.458260
# 2     0.744027  0.258759       0.532045  0.725679       0.685680    0.676472
# 3     0.706376  0.508234       0.493037  0.705415       0.639589    0.399867
# 4     0.770388  0.398665       0.412376  0.641844       0.821945    0.368070
# ...        ...       ...            ...       ...            ...         ...
# 6045  0.150718  0.508924       0.358406  0.158718       0.183983    0.175120
# 6046  0.115640  0.447685       0.498026  0.111533       0.168710    0.339027
# 6047  0.041152  0.395023       0.518446  0.058275       0.086727    0.188628
# 6048  0.160386  0.234001       0.176605  0.146005       0.209577    0.170315
# 6049  0.178878  0.516268       0.497185  0.234869       0.157617    0.272042
#
# ...

# %%
concatenate_normalized.to_csv('Pandas_ML_Project_SNR_Minus5.csv')
